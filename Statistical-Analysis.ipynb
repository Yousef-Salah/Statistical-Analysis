# %% [markdown]
# # Statistical Analysis Final Project

# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## Dataset Loading

# %%
df = pd.read_csv("dataset.csv")
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
df.rename(columns = {'class':'infected'}, inplace = True)
df
# Out:
#      Age  Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0     40    Male       No        Yes                 No      Yes         No
# 1     58    Male       No         No                 No      Yes         No
# 2     41    Male      Yes         No                 No      Yes        Yes
# 3     45    Male       No         No                Yes      Yes        Yes
# 4     60    Male      Yes        Yes                Yes      Yes        Yes
# ..   ...     ...      ...        ...                ...      ...        ...
# 515   39  Female      Yes        Yes                Yes       No        Yes
# 516   48  Female      Yes        Yes                Yes      Yes        Yes
# 517   58  Female      Yes        Yes                Yes      Yes        Yes
# 518   32  Female       No         No                 No      Yes         No
# 519   42    Male       No         No                 No       No         No
#
# ...

# %%
num_of_infected = df[df.infected == 'Positive'].shape[0]
num_of_infected
# Out:
# 320

# %%
relative_frequencies_partial_paresis = df['partial paresis'].value_counts(normalize=True)
relative_frequencies_partial_paresis
#شلل جزئي
# Out:
# No     0.569231
# Yes    0.430769
# Name: partial paresis, dtype: float64

# %%
relative_frequencies_muscle_stiffness = df['muscle stiffness'].value_counts(normalize=True)
relative_frequencies_muscle_stiffness
# صلابه في العضلات
# Out:
# No     0.625
# Yes    0.375
# Name: muscle stiffness, dtype: float64

# %%
relative_frequencies_Alopecia = df['Alopecia'].value_counts(normalize=True)
#داء الثعلبه
relative_frequencies_Alopecia
# Out:
# No     0.655769
# Yes    0.344231
# Name: Alopecia, dtype: float64

# %%
relative_frequencies_Obesity = df['Obesity'].value_counts(normalize=True)
#سمنة
relative_frequencies_Obesity
# Out:
# No     0.830769
# Yes    0.169231
# Name: Obesity, dtype: float64

# %%
relative_frequencies_class = df['infected'].value_counts(normalize=True)
#مصاب ولا لاء
relative_frequencies_class
# Out:
# Positive    0.615385
# Negative    0.384615
# Name: infected, dtype: float64

# %%
two_waytable_partial_paresis=pd.crosstab(df['infected'],df['partial paresis'] )
two_waytable_partial_paresis
# Out:
# partial paresis   No  Yes
# infected
# Negative         168   32
# Positive         128  192

# %%
df[(df.infected == 'Positive') & (df['partial paresis'] == 'Yes')].shape[0] / num_of_infected
# Out:
# 0.6

# %% [markdown]
# # Almost 60% of infected people having partial paresis

# %%
two_waytable_partial_paresis.plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='infected'>

# %%
two_waytable_muscle_stiffness=pd.crosstab(df['infected'],df['muscle stiffness'] )
two_waytable_muscle_stiffness
# Out:
# muscle stiffness   No  Yes
# infected
# Negative          140   60
# Positive          185  135

# %%
df[(df.infected == 'Positive') & (df['muscle stiffness'] == 'Yes')].shape[0] / num_of_infected
# Out:
# 0.421875

# %% [markdown]
# # Almost 42% of infected people having muscle stiffness

# %%
two_waytable_muscle_stiffness.plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='infected'>

# %%
two_waytable_Alopecia=pd.crosstab(df['infected'],df['Alopecia'] )
two_waytable_Alopecia
# Out:
# Alopecia   No  Yes
# infected
# Negative   99  101
# Positive  242   78

# %%
df[(df.infected == 'Positive') & (df['Alopecia'] == 'No')].shape[0] / num_of_infected
# Out:
# 0.75625

# %% [markdown]
# # Almost 76% of infected people don't having Alopecia

# %%
two_waytable_Alopecia.plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='infected'>

# %%
two_waytable_Obesity=pd.crosstab(df['infected'],df['Obesity'] )
two_waytable_Obesity
# Out:
# Obesity    No  Yes
# infected
# Negative  173   27
# Positive  259   61

# %%
df[(df.infected == 'Positive') & (df['Obesity'] == 'No')].shape[0] / num_of_infected
# Out:
# 0.809375

# %% [markdown]
# # Almost 80% of infected people don't having Obesity

# %%
two_waytable_Obesity.plot.bar(rot=0)
# Out:
# <AxesSubplot:xlabel='infected'>

# %%
def percentage_of_infected(df, column, condition_value='Yes'):
    num_of_infected = df[df.infected == 'Positive'].shape[0]
    
    return df[(df.infected == 'Positive') & (df[column] == condition_value)].shape[0] / num_of_infected
    

def relationship_percentage(df, column, condition_value, main_column):
    num_of_infected = df[df.infected == 'Positive'].shape[0]
    two_way_table = pd.crosstab(df[main_column], df[column])
    plot_title = "Relationship between " + column + " & Diabetes"
    two_way_table.plot.bar(rot=0, title=plot_title )
    percentage = df[(df[main_column] == 'Positive') & (df[column] == 'Yes')].shape[0] / num_of_infected
    # plt.savefig(columns[feature] + '_Diabetes.png',dpi=300)
    
    if(percentage < 0.25):
        print(f"This dataset shows that, there is a week Realtionship between {column} & Diabetes with percentage of {percentage}")
    
    elif(percentage >= 0.25 and percentage < 0.7 ):
          print(f"This dataset shows that, there is a Moderate relationship between {column} & Diabetes with percentage of {percentage}")
    else:
        print(f"This dataset shows that, there is a strong Realtionship between {column} & Diabetes with percentage of {percentage}")

# %%
columns = df.columns.tolist()

for feature in range(2, 16):
    relationship_percentage(df,columns[feature], 'Yes', 'infected')
# Out:
# This dataset shows that, there is a strong Realtionship between Polyuria & Diabetes with percentage of 0.759375
# This dataset shows that, there is a strong Realtionship between Polydipsia & Diabetes with percentage of 0.703125
# This dataset shows that, there is a Moderate relationship between sudden weight loss & Diabetes with percentage of 0.5875
# This dataset shows that, there is a Moderate relationship between weakness & Diabetes with percentage of 0.68125
# This dataset shows that, there is a Moderate relationship between Polyphagia & Diabetes with percentage of 0.590625
# This dataset shows that, there is a Moderate relationship between Genital thrush & Diabetes with percentage of 0.259375
# This dataset shows that, there is a Moderate relationship between visual blurring & Diabetes with percentage of 0.546875
# This dataset shows that, there is a Moderate relationship between Itching & Diabetes with percentage of 0.48125
# ...

# %%
two_way_table = pd.crosstab(df.infected, df['Gender'])
plot_title = "Relationship between Gender & Diabetes"
two_way_table.plot.pie(subplots=True, title=plot_title)

male_percentage = percentage_of_infected(df, 'Gender', 'Male')
female_percentage = percentage_of_infected(df, 'Gender', 'Female')

plt.savefig('Gender_Diabetes.png',dpi=500)

if(male_percentage < 0.25):
    print(f"This dataset shows that, there is a week Realtionship between Male & Diabetes with percentage of {male_percentage}")
elif(male_percentage >= 0.25 and male_percentage < 0.7 ):
    print(f"This dataset shows that, there is a Moderate relationshi between Male & Diabetes with percentage of {male_percentage}")
else:
    print(f"This dataset shows that, there is a strong Realtionship between Male & Diabetes with percentage of {male_percentage}")

if(female_percentage < 0.25):
    print(f"This dataset shows that, there is a week Realtionship between Female & Diabetes with percentage of {female_percentage}")
elif(female_percentage >= 0.25 and female_percentage < 0.7 ):
    print(f"This dataset shows that, there is a Moderate relationshi between Female & Diabetes with percentage of {female_percentage}")
else:
    print(f"This dataset shows that, there is a strong Realtionship between Female & Diabetes with percentage of {female_percentage}")
# Out:
# This dataset shows that, there is a Moderate relationshi between Male & Diabetes with percentage of 0.459375
# This dataset shows that, there is a Moderate relationshi between Female & Diabetes with percentage of 0.540625
