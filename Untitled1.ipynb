# %%
import pandas as pd

# %%
data = pd.read_json(r'FinalImages.json')
data
# Out:
#       id                                          img_thumb  \
# 0      0  ......
# 1      1  ......
# 2      2  ......
# 3      3  ......
# 4      4  ......
# ..   ...                                                ...
# 995  995  ......
# 996  996  ......
# 997  997  ......
# 998  998  ......
# 999  999  ......
#
#                                                 img_og               title  \
# 0    ......          ugly Icons
# 1    ......  blueprint Patterns
# 2    https://images.unsplash.com/photo-151981791415...    road Backgrounds
# 3    ......      colorful Icons
# 4    https://static.vecteezy.com/system/resources/p...     desert Patterns
# ..                                                 ...                 ...
# 995  https://static.vecteezy.com/system/resources/p...      simple Vectors
# 996  https://img.freepik.com/free-vector/modern-sof...    handsome Banners
# 997  https://i.pinimg.com/originals/55/68/3a/55683a...       dark Drawings
# ...

# %%
data[data.id.duplicated()].count().sum()
# Out:
# 0
